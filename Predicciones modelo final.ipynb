# %%
from google.colab import drive
drive.mount('/content/drive')
from sklearn.linear_model import LinearRegression
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/wind_ava.csv/wind_ava.csv')
#df = pd.read_csv('wind_ava.csv')
# Elimina los campos que no terminen en 13
columnas_a_mantener = df.columns[df.columns.str.endswith('13') | (df.columns == 'energy') | (df.columns == 'datetime')]
df = df[columnas_a_mantener]
df.to_csv('wind_ava_13.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Tras realizar el EDA, la alternativa que hemos escogido es el método de Regresión Lineal con los siguientes hiperparámetros: {'fit_intercept': False, 'positive': False}
